# %% [markdown]
# <a href="https://colab.research.google.com/github/CIDE7/Ciencia-de-daos-iesb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Lista de Exercícios 1 - Python Express

Introdução a Ciência de Dados

Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.

Cada exercício deve ser respondido em uma célula específica.

1.Elabore um código que imprima a mensagem "Olá terráqueos!!" na tela.

2.Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]."

3.Elabore um código que peça dois números e imprima a soma.

4.Elabore um código que peça as 4 notas bimestrais e mostre a média.

5.Elabore um código que converta metros para centímetros.

6.Elabore um código que peça o raio de um círculo, calcule e mostre sua área.

7.Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

8.Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.

9.Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.

10.Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.

11.Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:

o produto do dobro do primeiro com metade do segundo .
a soma do triplo do primeiro com o terceiro.
o terceiro elevado ao cubo.

12.Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
print("ola terráqueos!!")
# Out:
# ola terráqueos!!

# %%
numero = input("digite um número: ")
print("o número informado foi", numero)
# Out:
# digite um número: 15
# o número informado foi 15

# %%
n1 = float(input("digite o primeiro numero: "))
n2 = float(input("digite o segundo numero: "))
soma = n1 + n2
print("a soma é:", soma)
# Out:
# digite o primeiro numero: 8
# digite o segundo numero: 11
# a soma é: 19.0

# %%
n1 = float(input("nota 1: "))
n2 = float(input("nota 2: "))
n3 = float(input("nota 3: "))
n4 = float(input("nota 4: "))

media = (n1 + n2 + n3 + n4) / 4

print("A média é:", media)
# Out:
# nota 1: 5
# nota 2: 8
# nota 3: 6
# nota 4: 7
# A média é: 6.5

# %%
metros = float(input("digite a quantidade de metros:"))
cm = metros * 100
print ("Em centimetros:", cm )
# Out:
# digite a quantidade de metros:80
# Em centimetros: 8000.0

# %%
raio = float(input("digite o raio: "))
area = 3.14 * (raio ** 2)
print ("Area do circulo", area)
# Out:
# digite o raio: 9
# Area do circulo 254.34

# %%
lado = float(input("digite o lado do quadrado: "))
area = lado ** 2
dobro = area * 2
print("area:", area)
print("dobro da area:", dobro)
# Out:
# digite o lado do quadrado: 5
# area: 25.0
# dobro da area: 50.0

# %%
valor_hora = float(input("Quanto voce ganha por hora? "))
horas = float(input("Quantas horas voce trabalha por mes? "))
salario = valor_hora * horas
print ("Seu salario é: R$", salario)
# Out:
# Quanto voce ganha por hora? 51
# Quantas horas voce trabalha por mes? 40
# Seu salario é: R$ 2040.0

# %%
f = float (input("Temperatura fahrenheit: "))
c= 5 * ((f - 32) / 9)
print("Em celsius:", c)
# Out:
# Temperatura fahrenheit: 58
# Em celsius: 14.444444444444445

# %%
n1 = int(input("Primeiro numero inteiro: "))
n2 = int(input("Segundo numero inteiro: "))
n3 = float (input("Numero real: "))

# a)
a = (n1 * 2) * (n2 / 2)

# b)
b = (n1 * 3) + n3

# c)
c = n3 ** 3

print ("produto:", a)
print ("soma", b)
print ("cubo", c)
# Out:
# Primeiro numero inteiro: 17
# Segundo numero inteiro: 13
# Numero real: 5
# produto: 221.0
# soma 56.0
# cubo 125.0

# %%
altura = float(input("Digite sua altura: "))
peso_ideal = (72.7 * altura ) - 58
print (" Seu peso é:", peso_ideal)
# Out:
# Digite sua altura: 1.80
#  Seu peso é: 72.86000000000001
